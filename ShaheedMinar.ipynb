# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(layout='constrained')
ax.plot([40, 40], [0, 40])
ax.plot([40, 40-10], [40, 40+20])
ax.plot([45,40], [45, 40+20-5])
ax.plot([45, 50+2.5], [45, 45])
ax.plot([40, 45+5], [40+20-5, 40+20-5])
ax.plot([50, 50+2.5], [40+20-5, 45])

ax.plot([40+5, 40+5], [0, 35])
ax.plot([40+30, 40+30], [0, 40])
ax.plot([70, 80], [40, 40+20])
ax.plot([65, 70], [45, 40+20-5])
ax.plot([60-2.5, 65], [45, 45])
ax.plot([60, 70], [40+20-5, 40+20-5])
ax.plot([60-2.5, 60], [45, 40+20-5])

ax.plot([80, 30], [60, 60])
ax.plot([40, 70], [40, 40])
ax.plot([40+30-5, 40+30-5], [0, 35])
ax.plot([40+5, 55-2.5], [35, 35])
ax.plot([55+2.5, 40+30-5], [35, 35])
ax.plot([55-2.5, 55-2.5], [0, 35])
ax.plot([55+2.5, 55+2.5], [0, 35])

ax.plot([70+5, 70+5], [0, 35])
ax.plot([70+5+5, 70+5+5], [0, 30])
ax.plot([70+5+16, 70+5+16], [0, 35])
ax.plot([70+5+16-5, 70+5+16-5], [0, 30])
ax.plot([70+5, 70+5+16], [35, 35])
ax.plot([70+5+5, 70+5+16-5], [30, 30])

ax.plot([40-5, 40-5], [0, 35])
ax.plot([40-5-5, 40-5-5], [0, 30])
ax.plot([40-5-16, 40-5-16], [0, 35])
ax.plot([40-5-16+5, 40-5-16+5], [0, 30])
ax.plot([40-5, 40-5-16], [35, 35])
ax.plot([40-5-5, 40-5-16+5], [30, 30])

ax.plot([95, 95], [0, 30])
ax.plot([95+16, 95+16], [0, 30])
ax.plot([95, 95+16], [30, 30])

ax.plot([95+5, 95+5], [0, 25])
ax.plot([95+16-5, 95+16-5], [0, 25])
ax.plot([95+5, 95+16-5], [25, 25])

ax.plot([15, 15], [0, 30])
ax.plot([15-16, 15-16], [0, 30])
ax.plot([15, 15-16], [30, 30])

ax.plot([15-5, 15-5], [0, 25])
ax.plot([15-16+5, 15-16+5], [0, 25])
ax.plot([15-5, 15-16+5], [25, 25])
